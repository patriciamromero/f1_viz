# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_drivers= pd.read_csv('drivers_updated.csv', index_col= None)

# %%
df_laps = pd.read_csv("fastest_laps_.csv", index_col= None)

# %%
df.head()
# Out:
#   Pos                Driver Nationality          Car   PTS  year Code
# 0   1         Nino  Farina          ITA   Alfa Romeo  30.0  1950  FAR
# 1   2  Juan Manuel  Fangio          ARG   Alfa Romeo  27.0  1950  FAN
# 2   3       Luigi  Fagioli          ITA   Alfa Romeo  24.0  1950  FAG
# 3   4         Louis Rosier          FRA  Talbot-Lago  13.0  1950  ROS
# 4   5      Alberto  Ascari          ITA      Ferrari  11.0  1950  ASC

# %%
df_ALO = df[df['Code'] == 'ALO']

# %%
df_ALO = df_ALO.drop(df_ALO.index[-1])

# %%
df_ALO
# Out:
#      Pos             Driver Nationality           Car    PTS  year Code
# 1150   6  Fernando  Alonso          ESP       Renault   55.0  2003  ALO
# 1172   4  Fernando  Alonso          ESP       Renault   59.0  2004  ALO
# 1194   1  Fernando  Alonso          ESP       Renault  133.0  2005  ALO
# 1219   1  Fernando  Alonso          ESP       Renault  134.0  2006  ALO
# 1248   3  Fernando  Alonso          ESP       McLaren  109.0  2007  ALO
# 1275   5  Fernando  Alonso          ESP       Renault   61.0  2008  ALO
# 1301   9  Fernando  Alonso          ESP       Renault   26.0  2009  ALO
# 1319   2  Fernando  Alonso          ESP       Ferrari  252.0  2010  ALO
# 1348   4  Fernando  Alonso          ESP       Ferrari  257.0  2011  ALO
# 1374   2  Fernando  Alonso          ESP       Ferrari  278.0  2012  ALO
# 1399   2  Fernando  Alonso          ESP       Ferrari  242.0  2013  ALO
# 1426   6  Fernando  Alonso          ESP       Ferrari  161.0  2014  ALO
# ...

# %%
plt.bar(df_ALO["Car"], df_ALO['PTS'])
plt.title("Points per team ALO")
plt.xlabel("Team")
plt.ylabel("Points")
plt.show()

# %%
df_laps_ALO = df_laps[df_laps["Code"] == "ALO"]

# %%
df_laps_ALO
# Out:
#          Grand Prix             Driver                           Car  \
# 704          Canada  Fernando  Alonso                        Renault
# 731       Australia  Fernando  Alonso                        Renault
# 737          Europe  Fernando  Alonso                        Renault
# 751        Malaysia  Fernando  Alonso                        Renault
# 753      San Marino  Fernando  Alonso                        Renault
# 757   Great Britain  Fernando  Alonso                        Renault
# 765           China  Fernando  Alonso                        Renault
# 766           Japan  Fernando  Alonso                        Renault
# 772          Monaco  Fernando  Alonso               McLaren Mercedes
# 773          Canada  Fernando  Alonso               McLaren Mercedes
# 780           Italy  Fernando  Alonso               McLaren Mercedes
# 811         Germany  Fernando  Alonso                        Renault
# 816       Singapore  Fernando  Alonso                        Renault
# ...

# %%
def convertir_segundos(tiempo): 
    minutos, segundos = map(float, tiempo.split(":"))
    return minutos * 60 * segundos

df_laps_ALO["time_seconds"] = df_laps_ALO["Time"].apply(convertir_segundos)
# Out:
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_67435/3898464259.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_laps_ALO["time_seconds"] = df_laps_ALO["Time"].apply(convertir_segundos)

# %%
df_laps_ALO
# Out:
#          Grand Prix             Driver                           Car  \
# 704          Canada  Fernando  Alonso                        Renault
# 731       Australia  Fernando  Alonso                        Renault
# 737          Europe  Fernando  Alonso                        Renault
# 751        Malaysia  Fernando  Alonso                        Renault
# 753      San Marino  Fernando  Alonso                        Renault
# 757   Great Britain  Fernando  Alonso                        Renault
# 765           China  Fernando  Alonso                        Renault
# 766           Japan  Fernando  Alonso                        Renault
# 772          Monaco  Fernando  Alonso               McLaren Mercedes
# 773          Canada  Fernando  Alonso               McLaren Mercedes
# 780           Italy  Fernando  Alonso               McLaren Mercedes
# 811         Germany  Fernando  Alonso                        Renault
# 816       Singapore  Fernando  Alonso                        Renault
# ...

# %%
df_laps_ALO.columns
# Out:
# Index(['Grand Prix', 'Driver', 'Car', 'Time', 'year', 'Code', 'time_seconds'], dtype='object')

# %%
plt.scatter(x = df_laps_ALO['year'], y = df_laps_ALO['time_seconds'])
plt.title("Evolución de vueltas rápidas de Fernando Alonso", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Tiempo de vuelta rápida (segundos)", fontsize=12)
plt.legend(title="Grand Prix")
plt.show()
# Out:
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_67435/1824575901.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Grand Prix")
